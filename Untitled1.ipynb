# %%
import numpy as np               # Научные вычисления
import pandas as pd              # Обработка и анализ данных
import matplotlib as mpl         # Визуализация графиков
import matplotlib.pyplot as plt  # MATLAB-подобный способ построения графиков
import seaborn as sns            # Визуализация графиков (надстройка над matplotlib)
import urllib.request            # Работа с URL
import json                      # Кодирование и декодирование данные в удобном формате
import xmltodict                 # Преобразование XML документа в словарь
import requests                  # Отправка HTTP запросов
import os                        # Работа с файловой системой
import matplotlib.image as mpimg # Работа с изображениями

from pandas.api.types import CategoricalDtype # Категориальные данные
from datetime import datetime  # Работа со временем

from matplotlib.legend_handler import HandlerBase # Работа с легендой
from matplotlib.ticker import MaxNLocator # Работа с метками
from matplotlib.text import Text # Работа с текстом на графике
from skimage import transform # Трансформации изображений

pd.set_option('display.max_columns', None) # Максимальное количество отображаемых столбцов
pd.set_option('display.max_rows', None)    # Максимальное количество отображаемых строк

pkgs = {
    'Package': [
        'NumPy', 'Pandas', 'Matplotlib', 'Seaborn', 'Json', 'Xmltodict'],
    'Version': [i.__version__ for i in [np, pd, mpl, sns, json, xmltodict]]}

df_pkgs = pd.DataFrame(data = pkgs)   # Версии используемых библиотек
df_pkgs.head(None).style.hide_index() # Отображение первых N строк или все если указать None

#путь к товарам
path = 'https://raw.githubusercontent.com/Eorthus/stud/main/Dictionary2.xml'
# Считывание каталога товаров
with urllib.request.urlopen(path) as fd:
    catalog = json.loads(json.dumps(xmltodict.parse(fd.read().decode('utf-8'))))

print(catalog)
# Out:
# {'store': {'department': [{'@name_eng': 'Bakery', '@name_rus': 'Хлеб', 'product': [{'@id': '1', '@name_eng': 'Loaf', '@name_rus': 'Батон'}, {'@id': '2', '@name_eng': 'Cake', '@name_rus': 'Пончик'}, {'@id': '3', '@name_eng': 'Cookie', '@name_rus': 'Печенье'}]}, {'@name_eng': 'Milk', '@name_rus': 'Молоко', 'product': [{'@id': '4', '@name_eng': 'Milk', '@name_rus': 'Молоко'}, {'@id': '5', '@name_eng': 'Ice cream', '@name_rus': 'Мороженное'}, {'@id': '6', '@name_eng': 'Yoghurt', '@name_rus': 'Йогурт'}]}, {'@name_eng': 'Vegetables', '@name_rus': 'Овощи', 'product': [{'@id': '7', '@name_eng': 'Carrot', '@name_rus': 'Морковь'}, {'@id': '8', '@name_eng': 'Tomato', '@name_rus': 'Помидор'}, {'@id': '9', '@name_eng': 'Cucumber', '@name_rus': 'Огурец'}]}, {'@name_eng': 'Fruit', '@name_rus': 'Фрукты', 'product': [{'@id': '10', '@name_eng': 'Apple', '@name_rus': 'Яблоко'}, {'@id': '11', '@name_eng': 'Orange', '@name_rus': 'Апельсин'}, {'@id': '12', '@name_eng': 'Banana', '@name_rus': 'Банан'}]}, {'@name_eng': 'Groats', '@name_rus': 'Крупы и макароны', 'product': [{'@id': '13', '@name_eng': 'Pasta', '@name_rus': 'Макароны'}, {'@id': '14', '@name_eng': 'Buckwheat', '@name_rus': 'Греча'}, {'@id': '15', '@name_eng': 'Rice', '@name_rus': 'Рис'}]}, {'@name_eng': 'Conserve', '@name_rus': 'Консервация', 'product': [{'@id': '16', '@name_eng': 'Stew', '@name_rus': 'Тушенка'}, {'@id': '17', '@name_eng': 'Jam', '@name_rus': 'Варенье'}, {'@id': '18', '@name_eng': 'Sprats', '@name_rus': 'Шпроты'}]}, {'@name_eng': 'Semi-finished products', '@name_rus': 'Полуфабрикаты', 'product': [{'@id': '19', '@name_eng': 'Nuggets', '@name_rus': 'Наггетсы'}, {'@id': '20', '@name_eng': 'Pancakes', '@name_rus': 'Блины'}, {'@id': '21', '@name_eng': 'Pizza', '@name_rus': 'Пицца'}]}, {'@name_eng': 'Alcohol', '@name_rus': 'Алкоголь', 'product': [{'@id': '22', '@name_eng': 'Wine', '@name_rus': 'Вино'}, {'@id': '23', '@name_eng': 'Vodka', '@name_rus': 'Водка'}, {'@id': '24', '@name_eng': 'Whiskey', '@name_rus': 'Виски'}]}, {'@name_eng': 'Meat', '@name_rus': 'Мясо', 'product': [{'@id': '25', '@name_eng': 'Steak', '@name_rus': 'Отбивная'}, {'@id': '26', '@name_eng': 'Chicken', '@name_rus': 'Курица'}, {'@id': '27', '@name_eng': 'Sausage', '@name_rus': 'Сосиски'}]}, {'@name_eng': 'Drink', '@name_rus': 'Напитки', 'product': [{'@id': '28', '@name_eng': 'Water', '@name_rus': 'Вода'}, {'@id': '29', '@name_eng': 'Juice', '@name_rus': 'Сок'}, {'@id': '30', '@name_eng': 'Tea', '@name_rus': 'Чай'}]}]}}

# %%
catalog['store']['department']
# Out:
# [{'@name_eng': 'Bakery',
#   '@name_rus': 'Хлеб',
#   'product': [{'@id': '1', '@name_eng': 'Loaf', '@name_rus': 'Батон'},
#    {'@id': '2', '@name_eng': 'Cake', '@name_rus': 'Пончик'},
#    {'@id': '3', '@name_eng': 'Cookie', '@name_rus': 'Печенье'}]},
#  {'@name_eng': 'Milk',
#   '@name_rus': 'Молоко',
#   'product': [{'@id': '4', '@name_eng': 'Milk', '@name_rus': 'Молоко'},
#    {'@id': '5', '@name_eng': 'Ice cream', '@name_rus': 'Мороженное'},
#    {'@id': '6', '@name_eng': 'Yoghurt', '@name_rus': 'Йогурт'}]},
#  {'@name_eng': 'Vegetables',
#   '@name_rus': 'Овощи',
#   'product': [{'@id': '7', '@name_eng': 'Carrot', '@name_rus': 'Морковь'},
#    {'@id': '8', '@name_eng': 'Tomato', '@name_rus': 'Помидор'},
#    {'@id': '9', '@name_eng': 'Cucumber', '@name_rus': 'Огурец'}]},
#  {'@name_eng': 'Fruit',
#   '@name_rus': 'Фрукты',
#   'product': [{'@id': '10', '@name_eng': 'Apple', '@name_rus': 'Яблоко'},
#    {'@id': '11', '@name_eng': 'Orange', '@name_rus': 'Апельсин'},
#    {'@id': '12', '@name_eng': 'Banana', '@name_rus': 'Банан'}]},
#  {'@name_eng': 'Groats',
#   '@name_rus': 'Крупы и макароны',
#   'product': [{'@id': '13', '@name_eng': 'Pasta', '@name_rus': 'Макароны'},
#    {'@id': '14', '@name_eng': 'Buckwheat', '@name_rus': 'Греча'},
#    {'@id': '15', '@name_eng': 'Rice', '@name_rus': 'Рис'}]},
#  {'@name_eng': 'Conserve',
#   '@name_rus': 'Консервация',
#   'product': [{'@id': '16', '@name_eng': 'Stew', '@name_rus': 'Тушенка'},
#    {'@id': '17', '@name_eng': 'Jam', '@name_rus': 'Варенье'},
#    {'@id': '18', '@name_eng': 'Sprats', '@name_rus': 'Шпроты'}]},
#  {'@name_eng': 'Semi-finished products',
#   '@name_rus': 'Полуфабрикаты',
#   'product': [{'@id': '19', '@name_eng': 'Nuggets', '@name_rus': 'Наггетсы'},
#    {'@id': '20', '@name_eng': 'Pancakes', '@name_rus': 'Блины'},
#    {'@id': '21', '@name_eng': 'Pizza', '@name_rus': 'Пицца'}]},
#  {'@name_eng': 'Alcohol',
#   '@name_rus': 'Алкоголь',
#   'product': [{'@id': '22', '@name_eng': 'Wine', '@name_rus': 'Вино'},
#    {'@id': '23', '@name_eng': 'Vodka', '@name_rus': 'Водка'},
#    {'@id': '24', '@name_eng': 'Whiskey', '@name_rus': 'Виски'}]},
#  {'@name_eng': 'Meat',
#   '@name_rus': 'Мясо',
#   'product': [{'@id': '25', '@name_eng': 'Steak', '@name_rus': 'Отбивная'},
#    {'@id': '26', '@name_eng': 'Chicken', '@name_rus': 'Курица'},
#    {'@id': '27', '@name_eng': 'Sausage', '@name_rus': 'Сосиски'}]},
#  {'@name_eng': 'Drink',
#   '@name_rus': 'Напитки',
#   'product': [{'@id': '28', '@name_eng': 'Water', '@name_rus': 'Вода'},
#    {'@id': '29', '@name_eng': 'Juice', '@name_rus': 'Сок'},
#    {'@id': '30', '@name_eng': 'Tea', '@name_rus': 'Чай'}]}]

# %%
# Табличное представление
catalog = pd.DataFrame.from_dict(catalog['store']['department'])

catalog
# Out:
#                 @name_eng         @name_rus  \
# 0                  Bakery              Хлеб
# 1                    Milk            Молоко
# 2              Vegetables             Овощи
# 3                   Fruit            Фрукты
# 4                  Groats  Крупы и макароны
# 5                Conserve       Консервация
# 6  Semi-finished products     Полуфабрикаты
# 7                 Alcohol          Алкоголь
# 8                    Meat              Мясо
# 9                   Drink           Напитки
#
#                                              product
# 0  [{'@id': '1', '@name_eng': 'Loaf', '@name_rus'...
# 1  [{'@id': '4', '@name_eng': 'Milk', '@name_rus'...
# 2  [{'@id': '7', '@name_eng': 'Carrot', '@name_ru...
# 3  [{'@id': '10', '@name_eng': 'Apple', '@name_ru...
# 4  [{'@id': '13', '@name_eng': 'Pasta', '@name_ru...
# 5  [{'@id': '16', '@name_eng': 'Stew', '@name_rus...
# 6  [{'@id': '19', '@name_eng': 'Nuggets', '@name_...
# 7  [{'@id': '22', '@name_eng': 'Wine', '@name_rus...
# 8  [{'@id': '25', '@name_eng': 'Steak', '@name_ru...
# 9  [{'@id': '28', '@name_eng': 'Water', '@name_ru...

# %%
# Парсинг товаров
for e in ['@id', '@name_eng', '@name_rus']:
    catalog['product_' + e[1:]] = catalog['product'].apply(lambda x: x[e] if type(x) is dict else [v[e] for v in x])

catalog
# Out:
#                 @name_eng         @name_rus  \
# 0                  Bakery              Хлеб
# 1                    Milk            Молоко
# 2              Vegetables             Овощи
# 3                   Fruit            Фрукты
# 4                  Groats  Крупы и макароны
# 5                Conserve       Консервация
# 6  Semi-finished products     Полуфабрикаты
# 7                 Alcohol          Алкоголь
# 8                    Meat              Мясо
# 9                   Drink           Напитки
#
#                                              product    product_id  \
# 0  [{'@id': '1', '@name_eng': 'Loaf', '@name_rus'...     [1, 2, 3]
# 1  [{'@id': '4', '@name_eng': 'Milk', '@name_rus'...     [4, 5, 6]
# 2  [{'@id': '7', '@name_eng': 'Carrot', '@name_ru...     [7, 8, 9]
# 3  [{'@id': '10', '@name_eng': 'Apple', '@name_ru...  [10, 11, 12]
# 4  [{'@id': '13', '@name_eng': 'Pasta', '@name_ru...  [13, 14, 15]
# 5  [{'@id': '16', '@name_eng': 'Stew', '@name_rus...  [16, 17, 18]
# 6  [{'@id': '19', '@name_eng': 'Nuggets', '@name_...  [19, 20, 21]
# 7  [{'@id': '22', '@name_eng': 'Wine', '@name_rus...  [22, 23, 24]
# 8  [{'@id': '25', '@name_eng': 'Steak', '@name_ru...  [25, 26, 27]
# 9  [{'@id': '28', '@name_eng': 'Water', '@name_ru...  [28, 29, 30]
#
#              product_name_eng              product_name_rus
# 0        [Loaf, Cake, Cookie]      [Батон, Пончик, Печенье]
# 1  [Milk, Ice cream, Yoghurt]  [Молоко, Мороженное, Йогурт]
# 2  [Carrot, Tomato, Cucumber]    [Морковь, Помидор, Огурец]
# 3     [Apple, Orange, Banana]     [Яблоко, Апельсин, Банан]
# 4    [Pasta, Buckwheat, Rice]        [Макароны, Греча, Рис]
# 5         [Stew, Jam, Sprats]    [Тушенка, Варенье, Шпроты]
# 6  [Nuggets, Pancakes, Pizza]      [Наггетсы, Блины, Пицца]
# 7      [Wine, Vodka, Whiskey]          [Вино, Водка, Виски]
# 8   [Steak, Chicken, Sausage]   [Отбивная, Курица, Сосиски]
# 9         [Water, Juice, Tea]              [Вода, Сок, Чай]

# %%
# Удаление не нужного столбца, которого распарсили
catalog.drop(['product'], axis = 1, inplace = True)

catalog
# Out:
#                 @name_eng         @name_rus    product_id  \
# 0                  Bakery              Хлеб     [1, 2, 3]
# 1                    Milk            Молоко     [4, 5, 6]
# 2              Vegetables             Овощи     [7, 8, 9]
# 3                   Fruit            Фрукты  [10, 11, 12]
# 4                  Groats  Крупы и макароны  [13, 14, 15]
# 5                Conserve       Консервация  [16, 17, 18]
# 6  Semi-finished products     Полуфабрикаты  [19, 20, 21]
# 7                 Alcohol          Алкоголь  [22, 23, 24]
# 8                    Meat              Мясо  [25, 26, 27]
# 9                   Drink           Напитки  [28, 29, 30]
#
#              product_name_eng              product_name_rus
# 0        [Loaf, Cake, Cookie]      [Батон, Пончик, Печенье]
# 1  [Milk, Ice cream, Yoghurt]  [Молоко, Мороженное, Йогурт]
# 2  [Carrot, Tomato, Cucumber]    [Морковь, Помидор, Огурец]
# 3     [Apple, Orange, Banana]     [Яблоко, Апельсин, Банан]
# 4    [Pasta, Buckwheat, Rice]        [Макароны, Греча, Рис]
# 5         [Stew, Jam, Sprats]    [Тушенка, Варенье, Шпроты]
# 6  [Nuggets, Pancakes, Pizza]      [Наггетсы, Блины, Пицца]
# 7      [Wine, Vodka, Whiskey]          [Вино, Водка, Виски]
# 8   [Steak, Chicken, Sausage]   [Отбивная, Курица, Сосиски]
# 9         [Water, Juice, Tea]              [Вода, Сок, Чай]

# %%
# Преобразование списков в строки
catalog = catalog.set_index(['@name_eng', '@name_rus']).apply(lambda x: x.apply(pd.Series).stack()).reset_index().drop('level_2', 1)

catalog
# Out:
#                  @name_eng         @name_rus product_id product_name_eng  \
# 0                   Bakery              Хлеб          1             Loaf
# 1                   Bakery              Хлеб          2             Cake
# 2                   Bakery              Хлеб          3           Cookie
# 3                     Milk            Молоко          4             Milk
# 4                     Milk            Молоко          5        Ice cream
# 5                     Milk            Молоко          6          Yoghurt
# 6               Vegetables             Овощи          7           Carrot
# 7               Vegetables             Овощи          8           Tomato
# 8               Vegetables             Овощи          9         Cucumber
# 9                    Fruit            Фрукты         10            Apple
# 10                   Fruit            Фрукты         11           Orange
# 11                   Fruit            Фрукты         12           Banana
# 12                  Groats  Крупы и макароны         13            Pasta
# 13                  Groats  Крупы и макароны         14        Buckwheat
# 14                  Groats  Крупы и макароны         15             Rice
# 15                Conserve       Консервация         16             Stew
# 16                Conserve       Консервация         17              Jam
# 17                Conserve       Консервация         18           Sprats
# 18  Semi-finished products     Полуфабрикаты         19          Nuggets
# 19  Semi-finished products     Полуфабрикаты         20         Pancakes
# 20  Semi-finished products     Полуфабрикаты         21            Pizza
# 21                 Alcohol          Алкоголь         22             Wine
# 22                 Alcohol          Алкоголь         23            Vodka
# 23                 Alcohol          Алкоголь         24          Whiskey
# 24                    Meat              Мясо         25            Steak
# 25                    Meat              Мясо         26          Chicken
# 26                    Meat              Мясо         27          Sausage
# 27                   Drink           Напитки         28            Water
# 28                   Drink           Напитки         29            Juice
# 29                   Drink           Напитки         30              Tea
#
#    product_name_rus
# 0             Батон
# 1            Пончик
# 2           Печенье
# 3            Молоко
# 4        Мороженное
# 5            Йогурт
# 6           Морковь
# 7           Помидор
# 8            Огурец
# 9            Яблоко
# 10         Апельсин
# 11            Банан
# 12         Макароны
# 13            Греча
# 14              Рис
# 15          Тушенка
# 16          Варенье
# 17           Шпроты
# 18         Наггетсы
# 19            Блины
# 20            Пицца
# 21             Вино
# 22            Водка
# 23            Виски
# 24         Отбивная
# 25           Курица
# 26          Сосиски
# 27             Вода
# 28              Сок
# 29              Чай

# %%
# Переименование названий столбцов
catalog.rename(
    columns = {
        '@name_eng': 'Department_eng',
        '@name_rus': 'Department_rus',
        'product_id': 'ID_product',
        'product_name_eng': 'Product_eng',
        'product_name_rus': 'Product_rus'
    },
    inplace = True
)

catalog
# Out:
#             Department_eng    Department_rus ID_product Product_eng  \
# 0                   Bakery              Хлеб          1        Loaf
# 1                   Bakery              Хлеб          2        Cake
# 2                   Bakery              Хлеб          3      Cookie
# 3                     Milk            Молоко          4        Milk
# 4                     Milk            Молоко          5   Ice cream
# 5                     Milk            Молоко          6     Yoghurt
# 6               Vegetables             Овощи          7      Carrot
# 7               Vegetables             Овощи          8      Tomato
# 8               Vegetables             Овощи          9    Cucumber
# 9                    Fruit            Фрукты         10       Apple
# 10                   Fruit            Фрукты         11      Orange
# 11                   Fruit            Фрукты         12      Banana
# 12                  Groats  Крупы и макароны         13       Pasta
# 13                  Groats  Крупы и макароны         14   Buckwheat
# 14                  Groats  Крупы и макароны         15        Rice
# 15                Conserve       Консервация         16        Stew
# 16                Conserve       Консервация         17         Jam
# 17                Conserve       Консервация         18      Sprats
# 18  Semi-finished products     Полуфабрикаты         19     Nuggets
# 19  Semi-finished products     Полуфабрикаты         20    Pancakes
# 20  Semi-finished products     Полуфабрикаты         21       Pizza
# 21                 Alcohol          Алкоголь         22        Wine
# 22                 Alcohol          Алкоголь         23       Vodka
# 23                 Alcohol          Алкоголь         24     Whiskey
# 24                    Meat              Мясо         25       Steak
# 25                    Meat              Мясо         26     Chicken
# 26                    Meat              Мясо         27     Sausage
# 27                   Drink           Напитки         28       Water
# 28                   Drink           Напитки         29       Juice
# 29                   Drink           Напитки         30         Tea
#
#    Product_rus
# 0        Батон
# 1       Пончик
# 2      Печенье
# 3       Молоко
# 4   Мороженное
# 5       Йогурт
# 6      Морковь
# 7      Помидор
# 8       Огурец
# 9       Яблоко
# 10    Апельсин
# 11       Банан
# 12    Макароны
# 13       Греча
# 14         Рис
# 15     Тушенка
# 16     Варенье
# 17      Шпроты
# 18    Наггетсы
# 19       Блины
# 20       Пицца
# 21        Вино
# 22       Водка
# 23       Виски
# 24    Отбивная
# 25      Курица
# 26     Сосиски
# 27        Вода
# 28         Сок
# 29         Чай

# %%
# Добавление ID каждой категории
catalog['ID_department'] = catalog['Department_eng'].astype('category').cat.codes + 1

catalog
# Out:
#             Department_eng    Department_rus ID_product Product_eng  \
# 0                   Bakery              Хлеб          1        Loaf
# 1                   Bakery              Хлеб          2        Cake
# 2                   Bakery              Хлеб          3      Cookie
# 3                     Milk            Молоко          4        Milk
# 4                     Milk            Молоко          5   Ice cream
# 5                     Milk            Молоко          6     Yoghurt
# 6               Vegetables             Овощи          7      Carrot
# 7               Vegetables             Овощи          8      Tomato
# 8               Vegetables             Овощи          9    Cucumber
# 9                    Fruit            Фрукты         10       Apple
# 10                   Fruit            Фрукты         11      Orange
# 11                   Fruit            Фрукты         12      Banana
# 12                  Groats  Крупы и макароны         13       Pasta
# 13                  Groats  Крупы и макароны         14   Buckwheat
# 14                  Groats  Крупы и макароны         15        Rice
# 15                Conserve       Консервация         16        Stew
# 16                Conserve       Консервация         17         Jam
# 17                Conserve       Консервация         18      Sprats
# 18  Semi-finished products     Полуфабрикаты         19     Nuggets
# 19  Semi-finished products     Полуфабрикаты         20    Pancakes
# 20  Semi-finished products     Полуфабрикаты         21       Pizza
# 21                 Alcohol          Алкоголь         22        Wine
# 22                 Alcohol          Алкоголь         23       Vodka
# 23                 Alcohol          Алкоголь         24     Whiskey
# 24                    Meat              Мясо         25       Steak
# 25                    Meat              Мясо         26     Chicken
# 26                    Meat              Мясо         27     Sausage
# 27                   Drink           Напитки         28       Water
# 28                   Drink           Напитки         29       Juice
# 29                   Drink           Напитки         30         Tea
#
#    Product_rus  ID_department
# 0        Батон              2
# 1       Пончик              2
# 2      Печенье              2
# 3       Молоко              8
# 4   Мороженное              8
# 5       Йогурт              8
# 6      Морковь             10
# 7      Помидор             10
# 8       Огурец             10
# 9       Яблоко              5
# 10    Апельсин              5
# 11       Банан              5
# 12    Макароны              6
# 13       Греча              6
# 14         Рис              6
# 15     Тушенка              3
# 16     Варенье              3
# 17      Шпроты              3
# 18    Наггетсы              9
# 19       Блины              9
# 20       Пицца              9
# 21        Вино              1
# 22       Водка              1
# 23       Виски              1
# 24    Отбивная              7
# 25      Курица              7
# 26     Сосиски              7
# 27        Вода              4
# 28         Сок              4
# 29         Чай              4

# %%
# Сортировка столбцов
capitalizу = ['ID_department', 'Department_eng', 'Department_rus', 'ID_product', 'Product_eng', 'Product_rus']

catalog = catalog[capitalizу] # Изменение позиции столбцов

catalog
# Out:
#     ID_department          Department_eng    Department_rus ID_product  \
# 0               2                  Bakery              Хлеб          1
# 1               2                  Bakery              Хлеб          2
# 2               2                  Bakery              Хлеб          3
# 3               8                    Milk            Молоко          4
# 4               8                    Milk            Молоко          5
# 5               8                    Milk            Молоко          6
# 6              10              Vegetables             Овощи          7
# 7              10              Vegetables             Овощи          8
# 8              10              Vegetables             Овощи          9
# 9               5                   Fruit            Фрукты         10
# 10              5                   Fruit            Фрукты         11
# 11              5                   Fruit            Фрукты         12
# 12              6                  Groats  Крупы и макароны         13
# 13              6                  Groats  Крупы и макароны         14
# 14              6                  Groats  Крупы и макароны         15
# 15              3                Conserve       Консервация         16
# 16              3                Conserve       Консервация         17
# 17              3                Conserve       Консервация         18
# 18              9  Semi-finished products     Полуфабрикаты         19
# 19              9  Semi-finished products     Полуфабрикаты         20
# 20              9  Semi-finished products     Полуфабрикаты         21
# 21              1                 Alcohol          Алкоголь         22
# 22              1                 Alcohol          Алкоголь         23
# 23              1                 Alcohol          Алкоголь         24
# 24              7                    Meat              Мясо         25
# 25              7                    Meat              Мясо         26
# 26              7                    Meat              Мясо         27
# 27              4                   Drink           Напитки         28
# 28              4                   Drink           Напитки         29
# 29              4                   Drink           Напитки         30
#
#    Product_eng Product_rus
# 0         Loaf       Батон
# 1         Cake      Пончик
# 2       Cookie     Печенье
# 3         Milk      Молоко
# 4    Ice cream  Мороженное
# 5      Yoghurt      Йогурт
# 6       Carrot     Морковь
# 7       Tomato     Помидор
# 8     Cucumber      Огурец
# 9        Apple      Яблоко
# 10      Orange    Апельсин
# 11      Banana       Банан
# 12       Pasta    Макароны
# 13   Buckwheat       Греча
# 14        Rice         Рис
# 15        Stew     Тушенка
# 16         Jam     Варенье
# 17      Sprats      Шпроты
# 18     Nuggets    Наггетсы
# 19    Pancakes       Блины
# 20       Pizza       Пицца
# 21        Wine        Вино
# 22       Vodka       Водка
# 23     Whiskey       Виски
# 24       Steak    Отбивная
# 25     Chicken      Курица
# 26     Sausage     Сосиски
# 27       Water        Вода
# 28       Juice         Сок
# 29         Tea         Чай

# %%
#. Установка индексов
catalog.set_index('ID_product', inplace = True)
catalog.index = catalog.index.map(str)

catalog.head(20)
# Out:
#             ID_department          Department_eng    Department_rus  \
# ID_product
# 1                       2                  Bakery              Хлеб
# 2                       2                  Bakery              Хлеб
# 3                       2                  Bakery              Хлеб
# 4                       8                    Milk            Молоко
# 5                       8                    Milk            Молоко
# 6                       8                    Milk            Молоко
# 7                      10              Vegetables             Овощи
# 8                      10              Vegetables             Овощи
# 9                      10              Vegetables             Овощи
# 10                      5                   Fruit            Фрукты
# 11                      5                   Fruit            Фрукты
# 12                      5                   Fruit            Фрукты
# 13                      6                  Groats  Крупы и макароны
# 14                      6                  Groats  Крупы и макароны
# 15                      6                  Groats  Крупы и макароны
# 16                      3                Conserve       Консервация
# 17                      3                Conserve       Консервация
# 18                      3                Conserve       Консервация
# 19                      9  Semi-finished products     Полуфабрикаты
# 20                      9  Semi-finished products     Полуфабрикаты
#
#            Product_eng Product_rus
# ID_product
# 1                 Loaf       Батон
# 2                 Cake      Пончик
# 3               Cookie     Печенье
# 4                 Milk      Молоко
# 5            Ice cream  Мороженное
# 6              Yoghurt      Йогурт
# 7               Carrot     Морковь
# 8               Tomato     Помидор
# 9             Cucumber      Огурец
# 10               Apple      Яблоко
# 11              Orange    Апельсин
# 12              Banana       Банан
# 13               Pasta    Макароны
# 14           Buckwheat       Греча
# 15                Rice         Рис
# 16                Stew     Тушенка
# 17                 Jam     Варенье
# 18              Sprats      Шпроты
# 19             Nuggets    Наггетсы
# 20            Pancakes       Блины

# %%
# Базовый класс легенды
class TextHandler(HandlerBase):
    def create_artists(self, legend, tup, xdescent, ydescent, width, height, fontsize, trans):
        tx = Text(
            width / 1.3,
            height / 4,
            tup[0],
            fontsize = fontsize,
            ha = 'center',
            va = 'center',
            color = tup[1],
            fontweight = 'bold'
        )
        
        return [tx]

def _countplot(df, pad):
    """
    График подсчета количества элементов

    (pandas.core.frame.DataFrame, int) -> None

    Аргументы:
        df - Данные
        pad - Отступ от ряда до его значения

    Возвращает: None
    """

    # Создание новой фигуры
    plt.figure(
        figsize = (4, 6) # Размер фигуры в дюймах
    )
    
    # Установка эстетических параметров
    sns.set(
        style = 'white', # Стиль
        palette = 'muted', # Пальтра
        color_codes = True,
        rc = {'lines.linewidth': 2.7}
    )
    sns.despine(left = True)
    mpl.rcParams['axes.linewidth'] = 1 # Толщина рамки

    ax = plt.axes() # Добавление осей к текущей фигуре
    ax.xaxis.tick_bottom() # Перемещение меток в нижнюю часть

    # Количество элементов в каждом классе
    ax = sns.countplot(df.ID_department, label = 'Количество')
    
    counts = df.groupby(df.ID_department).Department_eng.count().index.tolist()

    for i, p in enumerate(ax.patches):
        height = p.get_height()

        ax.text(
            p.get_x() + p.get_width() / 2.0, # X позиция размещения текста
            height + pad, # Y позиция размещения текста
            df.ID_department.value_counts()[counts[i]], # Текст
            ha = 'center', # Выравнивание
            fontdict = {
                'fontsize': 14, # Размер заголовка
                'color': '#000000' # Цвет заголовка
            },
        )

    # Изменение внешнего вида меток
    ax.tick_params(
        axis = 'x', # Ось
        direction = 'out', # Расположение линий меток
        length = 10, # Длина линий меток
        width = 1, # Ширина линий меток 
        color = '#999A99', # Цвет линий меток
        pad = 5, # Расстояние между линиями меток и метками
        labelsize = 14, # Размер метки
        labelcolor = '#000000', # Цвет метки
        bottom = True,  # Рисование линий меток
    )
    ax.tick_params(
        axis = 'y', # Ось
        direction = 'out', # Расположение линий меток
        length = 10, # Длина линий меток
        width = 1, # Ширина линий меток 
        color = '#999A99', # Цвет линий меток
        pad = 5, # Расстояние между линиями меток и метками
        labelsize = 14, # Размер метки
        labelcolor = '#000000', # Цвет метки
        left = True  # Рисование линий меток
    )

    # Заголовок осей
    ax.set_title(
        label = 'Количество товаров в каждой категории', # Заголовок
        fontdict = {
            'fontsize': 18, # Размер заголовка
            'color': '#000000' # Цвет заголовка
        },
        pad = 10 # Отступ заголовка от вершины осей
    )

    # Изменение внешнего вида меток данных
    ax.set_xlabel(
        'ID категорий',
        fontsize = 14, # Размер метки
        fontdict = {
            'color': '#000000' # Цвет метки
        },
        labelpad = 10 # Отступ

    )
    ax.set_ylabel(
        'Количество товаров',
        fontsize = 14, # Размер метки
        fontdict = {
            'color': '#000000' # Цвет метки
        },
        labelpad = 5 # Отступ
    )
    
    plt.setp(ax.spines.values(), color = '#999A99') # Цвет рамки
    
    ax.yaxis.set_major_locator(MaxNLocator(integer = True))

    xticklabels = ax.get_xticklabels() # Метки X
    
    # Словарь из ID и названий категорий
    labels = dict(zip(df.ID_department, df.Department_rus))
    
    labels = [labels[int(h.get_text())]  for h in xticklabels]
    handles = [(h.get_text(), c.get_fc()) for h, c in zip(xticklabels, ax.patches)]
    
    ax.legend(
        handles,
        labels,
        handler_map = {tuple : TextHandler()},
        bbox_to_anchor = (1., 1),
        borderaxespad = 0,
        frameon = False,
        fontsize = 16,
        title = ' Категории',
        title_fontsize = 16
    )
    
    plt.show() # Отображение фигуры

_countplot(catalog, 0.015)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b4580cc3b1a1> in <module>
# ----> 1 catalog.to_csv(
#       2     r'http://localhost:8888/lab/tree/NEW.csv', index = True, header = True
#       3 )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     309
#     310     def _save(self) -> None:
# --> 311         self._save_header()
#     312
#     313         nrows = len(self.data_index)
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_header(self)
#     278         if not has_mi_columns or has_aliases:
#     279             encoded_labels += list(write_cols)
# --> 280             writer.writerow(encoded_labels)
#     281         else:
#     282             # write out the mi
#
# TypeError: a bytes-like object is required, not 'str'

# %%
image_types = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')


def list_images(basePath, contains = None):
    return list_files(basePath, validExts = image_types, contains = contains)


def list_files(basePath, validExts = None, contains = None):
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        for filename in filenames:
            if contains is not None and filename.find(contains) == -1:
                continue

            ext = filename[filename.rfind('.'):].lower()

            if validExts is None or ext.endswith(validExts):
                imagePath = os.path.join(rootDir, filename)
                yield imagePath

# %%
urls = r'E:\documents\chert\rumin\two\urls\apple.txt'
dir_output = 'E:\documents\ipple'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:22:23] Ошибка при чтении "00000017.jpg" ... удаление ...
# [2020-10-28 22:22:24] Ошибка при чтении "00000048.jpg" ... удаление ...
# [2020-10-28 22:22:24] Всего файлов загружено: 44 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\orange.txt'
dir_output = 'E:\documents\orange'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:23:32] Ошибка при чтении "00000001.jpg" ... удаление ...
# [2020-10-28 22:23:32] Ошибка при чтении "00000007.jpg" ... удаление ...
# C:\Users\Oslickia\anaconda3\lib\site-packages\PIL\Image.py:2929: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# [2020-10-28 22:23:33] Ошибка при чтении "00000035.jpg" ... удаление ...
# [2020-10-28 22:23:34] Всего файлов загружено: 45 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\banana.txt'
dir_output = 'E:\documents\panana'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:25:33] Ошибка при чтении "00000038.jpg" ... удаление ...
# [2020-10-28 22:25:33] Всего файлов загружено: 47 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\carrot.txt'
dir_output = 'E:\documents\carrot'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:26:23] Всего файлов загружено: 46 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\tomato.txt'
dir_output = 'E:\documents\omato'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:27:29] Ошибка при чтении "00000010.jpg" ... удаление ...
# [2020-10-28 22:27:29] Ошибка при чтении "00000015.jpg" ... удаление ...
# [2020-10-28 22:27:30] Всего файлов загружено: 45 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\cucumber.txt'
dir_output = 'E:\documents\cucumber'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:29:58] Ошибка при чтении "00000004.jpg" ... удаление ...
# [2020-10-28 22:29:58] Ошибка при чтении "00000006.jpg" ... удаление ...
# [2020-10-28 22:30:00] Ошибка при чтении "00000032.jpg" ... удаление ...
# [2020-10-28 22:30:00] Всего файлов загружено: 43 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\loaf.txt'
dir_output = 'E:\documents\loaf'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:30:53] Ошибка при чтении "00000015.jpg" ... удаление ...
# [2020-10-28 22:30:54] Ошибка при чтении "00000034.jpg" ... удаление ...
# [2020-10-28 22:30:54] Всего файлов загружено: 44 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\cake.txt'
dir_output = 'E:\documents\cake'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:32:18] Ошибка при чтении "00000006.jpg" ... удаление ...
# [2020-10-28 22:32:18] Ошибка при чтении "00000009.jpg" ... удаление ...
# [2020-10-28 22:32:21] Всего файлов загружено: 44 ...

# %%
urls = r'E:\documents\chert\rumin\two\urls\cookie.txt'
dir_output = 'E:\documents\cookie'
def download(urls, dir_output):
    # ------------------------------------------------------------------------------------------------------------------

    green = '\033[92m'  # Зеленый
    red = '\033[91m'  # Красный
    bold = '\033[1m'  # Жирный
    end = '\033[0m'  # Выход

    format_time = '%Y-%m-%d %H:%M:%S'  # Формат времени

    # ------------------------------------------------------------------------------------------------------------------

    # Файл не найден
    if os.path.isfile(urls) is False:
        print('[{}{}{}] Файл "{}" не найден ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    _, ext = os.path.splitext(urls)  # Расширение файла

    if ext.replace('.', '') != 'txt':
        print('[{}{}{}] Расширение файла должно быть "{}" ...'.format(
            red, datetime.now().strftime(format_time), end, 'txt'
        ))
        return False

    if os.stat(urls).st_size == 0:
        print('[{}{}{}] Файл "{}" пуст ...'.format(
            red, datetime.now().strftime(format_time), end, os.path.basename(urls)
        ))
        return False

    # Создание директории, куда будут сохранены изображения, если она не существует
    if not os.path.exists(dir_output):
        os.makedirs(dir_output)

    # ------------------------------------------------------------------------------------------------------------------

    # Список URL-адресов из входного текстового файла
    urls = open(urls).read().strip().split('\n')

    # Проход по всем url
    for i, url in enumerate(urls):
        i += 1

        try:
            req = requests.get(url, timeout = 10)  # Отправка запроса GET

            # Сохранение изображения в указанную директорию
            path = os.path.sep.join([dir_output, '{}.jpg'.format(str(i).zfill(8))])

            with open(path, 'wb') as file:
                file.write(req.content)
        except:
            pass

    # ------------------------------------------------------------------------------------------------------------------

    all_download_files = 0  # Общее количество загруженных изображений

    # Проверка скачанных файлов
    for imagePath in list_images(dir_output):
        delete = False  # По умолчанию файл не должен быть удален

        try:
            image = mpl.pyplot.imread(imagePath)  # Попытка чтения изображения

            # Удаление файла если он не прочитан
            if image is None:
                delete = True
            else:
                all_download_files += 1
        except:
            delete = True

        # Удаление файла
        if delete:
            print('[{}{}{}] Ошибка при чтении "{}" ... удаление ...'.format(
                red, datetime.now().strftime(format_time), end, os.path.basename(imagePath)
            ))
            os.remove(imagePath)

    print('[{}{}{}] Всего файлов загружено: {}{}{} ...'.format(
        green, datetime.now().strftime(format_time), end, bold, all_download_files, end
    ))

# %%
res = download(urls, dir_output)
# Out:
# [2020-10-28 22:33:41] Всего файлов загружено: 48 ...

# %%
base_dir = 'E:\documents\mag' # Директория с БД

department = ['apple', 'orange', 'banana', 'carrot', 'tomato', 'cucumber', 'loaf', 'cake', 'cookie'] # Названия категорий

# %%
list_of_files = {} # Словарь для DataFrame
# Проход по всем категориям
for curr in department:
    # Формирование словаря для DataFrame
    list_of_files[curr] = os.listdir(os.path.join(base_dir, curr))

# Отображение в DataFrame
df_files = pd.DataFrame.from_dict(data = list_of_files, orient = 'index').transpose()
df_files[:10].head(None) # Отображение первых N строк или все если указать None
# Out:
#           apple        orange        banana        carrot        tomato  \
# 0  00000001.jpg  00000002.jpg  00000001.jpg  00000001.jpg  00000001.jpg
# 1  00000002.jpg  00000003.jpg  00000002.jpg  00000002.jpg  00000002.jpg
# 2  00000003.jpg  00000004.jpg  00000003.jpg  00000003.jpg  00000003.jpg
# 3  00000004.jpg  00000005.jpg  00000004.jpg  00000005.jpg  00000004.jpg
# 4  00000005.jpg  00000006.jpg  00000005.jpg  00000006.jpg  00000005.jpg
# 5  00000006.jpg  00000008.jpg  00000006.jpg  00000008.jpg  00000006.jpg
# 6  00000007.jpg  00000009.jpg  00000007.jpg  00000009.jpg  00000007.jpg
# 7  00000008.jpg  00000010.jpg  00000008.jpg  00000010.jpg  00000008.jpg
# 8  00000010.jpg  00000011.jpg  00000009.jpg  00000011.jpg  00000009.jpg
# 9  00000011.jpg  00000012.jpg  00000010.jpg  00000012.jpg  00000011.jpg
#
#        cucumber          loaf          cake        cookie
# 0  00000001.jpg  00000001.jpg  00000001.jpg  00000001.jpg
# 1  00000002.jpg  00000003.jpg  00000002.jpg  00000002.jpg
# 2  00000003.jpg  00000004.jpg  00000003.jpg  00000003.jpg
# 3  00000005.jpg  00000005.jpg  00000004.jpg  00000004.jpg
# 4  00000007.jpg  00000006.jpg  00000005.jpg  00000005.jpg
# 5  00000008.jpg  00000008.jpg  00000007.jpg  00000006.jpg
# 6  00000009.jpg  00000009.jpg  00000008.jpg  00000007.jpg
# 7  00000010.jpg  00000010.jpg  00000010.jpg  00000008.jpg
# 8  00000011.jpg  00000011.jpg  00000011.jpg  00000009.jpg
# 9  00000012.jpg  00000012.jpg  00000012.jpg  00000010.jpg

# %%
dict_dep = {'apple':0, 'orange':1, 'banana':2, 'carrot':3, 'tomato':4, 'cucumber':5, 'loaf':6, 'cake':7, 'cookie':8}

dict_dep = pd.DataFrame.from_dict(dict_dep, orient = 'index', columns = ['ID'])
dict_dep.head(None) # Отображение первых N строк или все если указать None
# Out:
#           ID
# apple      0
# orange     1
# banana     2
# carrot     3
# tomato     4
# cucumber   5
# loaf       6
# cake       7
# cookie     8

# %%
# Базовый класс легенды
class TextHandler(HandlerBase):
    def create_artists(self, legend, tup, xdescent, ydescent, width, height, fontsize, trans):
        tx = Text(
            width / 1.3,
            height / 4,
            tup[0],
            fontsize = fontsize,
            ha = 'center',
            va = 'center',
            color = tup[1],
            fontweight = 'bold'
        )
        
        return [tx]

def _countplot(df, pad):
    """
    График подсчета количества элементов

    (pandas.core.frame.DataFrame, int) -> None

    Аргументы:
        df - Данные
        pad - Отступ от ряда до его значения

    Возвращает: None
    """

    # Создание новой фигуры
    plt.figure(
        figsize = (10, 7) # Размер фигуры в дюймах
    )

    # Установка эстетических параметров
    sns.set(
        style = 'white', # Стиль
        palette = 'muted', # Пальтра
        color_codes = True,
        rc = {'lines.linewidth': 2.7}
    )
    sns.despine(left = True)
    mpl.rcParams['axes.linewidth'] = 1 # Толщина рамки
    
    ax = plt.axes() # Добавление осей к текущей фигуре
    ax.xaxis.tick_bottom() # Перемещение меток в нижнюю часть

    # Количество элементов в каждом классе
    ax = sns.countplot(df.ID, label = 'Количество', palette = ['#008400', '#840B00', '#757474', '#741484'])
    
    counts = df.groupby(df.ID).variable.count().index.tolist()
    
    for i, p in enumerate(ax.patches):
        height = p.get_height()

        ax.text(
            p.get_x() + p.get_width() / 2.0, # X позиция размещения текста
            height + pad, # Y позиция размещения текста
            df.ID.value_counts()[counts[i]], # Текст
            ha = 'center', # Выравнивание
            fontdict = {
                'fontsize': 14, # Размер заголовка
                'color': '#000000' # Цвет заголовка
            },
        )

    # Изменение внешнего вида меток
    ax.tick_params(
        axis = 'x', # Ось
        direction = 'out', # Расположение линий меток
        length = 10, # Длина линий меток
        width = 1, # Ширина линий меток 
        color = '#999A99', # Цвет линий меток
        pad = 5, # Расстояние между линиями меток и метками
        labelsize = 14, # Размер метки
        labelcolor = '#000000', # Цвет метки
        bottom = True,  # Рисование линий меток
    )
    ax.tick_params(
        axis = 'y', # Ось
        direction = 'out', # Расположение линий меток
        length = 10, # Длина линий меток
        width = 1, # Ширина линий меток 
        color = '#999A99', # Цвет линий меток
        pad = 5, # Расстояние между линиями меток и метками
        labelsize = 14, # Размер метки
        labelcolor = '#000000', # Цвет метки
        left = True  # Рисование линий меток
    )

    # Заголовок осей
    ax.set_title(
        label = 'Количество товаров в каждой категории', # Заголовок
        fontdict = {
            'fontsize': 18, # Размер заголовка
            'color': '#000000' # Цвет заголовка
        },
        pad = 10 # Отступ заголовка от вершины осей
    )

    # Изменение внешнего вида меток данных
    ax.set_xlabel(
        'ID категорий',
        fontsize = 14, # Размер метки
        fontdict = {
            'color': '#000000' # Цвет метки
        },
        labelpad = 10 # Отступ

    )
    ax.set_ylabel(
        'Количество товаров',
        fontsize = 14, # Размер метки
        fontdict = {
            'color': '#000000' # Цвет метки
        },
        labelpad = 5 # Отступ
    )
    
    plt.setp(ax.spines.values(), color = '#999A99') # Цвет рамки
    
    ax.yaxis.set_major_locator(MaxNLocator(integer = True))

    xticklabels = ax.get_xticklabels() # Метки X
    
    # Словарь из ID и названий категорий
    labels = dict(zip(df.ID, df.variable))
    
    labels = [labels[int(h.get_text())]  for h in xticklabels]
    handles = [(h.get_text(), c.get_fc()) for h, c in zip(xticklabels, ax.patches)]
    
    ax.legend(
        handles,
        labels,
        handler_map = {tuple : TextHandler()},
        bbox_to_anchor = (1., 1),
        borderaxespad = 0,
        frameon = False,
        fontsize = 16,
    )
    
    plt.show() # Отображение фигуры

data = df_files.melt(value_vars = df_files.columns).dropna()

columns = []

for curr in dict_dep.index.tolist():
    columns.append(curr)

# Добавление ID каждой категории
data['ID'] = data['variable'].astype(CategoricalDtype(categories = columns)).cat.codes + 1

_countplot(data, 4)

# %%
resize_img = (150, 150, 3) # Размер изображения

nrows = len(dict_dep.index) # Количество строк
ncols = 8 # Количество столбцов

samples = ncols # Количество примеров

fig = plt.gcf() # Создание фигуры
fig.set_size_inches(ncols * 2.2, nrows * 2.25) # Установка размера фигуры в дюймах

mpl.rcParams['axes.linewidth'] = 0 # Толщина рамки

idx_show = [] # Метки которые уже были показаны

i = 0 # Счетчик

for curr in dict_dep.index.tolist():
    # Случайная выборка
    idx_show = data.where(data.variable == curr).dropna().sample(n = samples)
    
    for var, val in zip(idx_show.variable, idx_show.value):        
        sp = plt.subplot(nrows, ncols, i + 1)
        
        # Скрытие осей
        plt.setp(sp.get_xticklabels(), visible = False)
        plt.setp(sp.get_yticklabels(), visible = False)
        plt.xticks([])
        plt.yticks([])

        path_to_img = os.path.join(base_dir, curr, val)

        img = mpimg.imread(path_to_img)

        # Уменьшение изображения
        img_small = transform.resize(img, resize_img)

        plt.imshow(img_small)
        
        if i % samples == 0:
            label = var.split('_') # Метка
            
            sp.set_ylabel(
                label[0],
                fontsize = 16, # Размер метки
                fontdict = {
                    'color': '#000000' # Цвет метки
                },
                labelpad = 4 # Отступ
            )
        
        i += 1

plt.suptitle(
    'Отображение изображений из обучающей выборки', # Заголовок
    fontsize = 20, # Размер заголовка
    fontdict = {
        'color': '#000000' # Цвет заголовка
    },
    y = 1.045 # Отступ заголовка от вершины осей
)

plt.tight_layout(pad = 0) # Установка расстояния между осями

plt.show() # Отображение фигуры
